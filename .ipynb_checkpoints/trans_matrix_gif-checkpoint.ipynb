# %%
import sys
module_path = '../modules/'
if module_path not in sys.path:
    sys.path.append(module_path)
from xT import *
import seaborn as sns
import matplotlib.pyplot as plt
import glob
from PIL import Image
import os

#Dimensions
l=16
w=8

data=pd.read_csv('scouting/data.csv')
xTModel = ExpectedThreat(l, w)
xTModel.fit(data)

per_lst = []
for i in [.25,.50,.75,.90]:
    percentile = np.quantile(xTModel.xT.reshape(128,1),i)
    per_lst.append(percentile)
    
cell_coord = []
for n in range(0,w):
    for m in range(0,l):
        cell_coord.append((m,n))

for i in range(0,w*l):
    x=cell_coord[i][0]
    y=cell_coord[i][1]
    uniform_data = pd.DataFrame(xTModel.transition_matrix[i].reshape(w,l))
    uniform_data.loc[y,x] = np.nan
    mask = uniform_data.isnull()
    shoot_p = xTModel.shot_prob_matrix[y][x]
    goal_p = xTModel.scoring_prob_matrix[y][x]
    xt = xTModel.xT[y][x]
    conditions = [
    (xt >= per_lst[3]),
    ((xt >= per_lst[2]) & (xt < per_lst[3])),
    ((xt >= per_lst[1]) & (xt < per_lst[2])),
    ((xt >= per_lst[0]) & (xt < per_lst[1])),
    ((xt < per_lst[0]))
    ]
    choices = ['#ff0000','#ff5900','#ff8800','#ffa500','#ffbf00']
    color=np.select(conditions, choices).tolist()
    figure = plt.gcf()
    figure.set_size_inches((200/15), (85/15))
    sns.set_context("paper", font_scale=2)
    ax = sns.heatmap(uniform_data,cmap="Blues",mask=mask)
    ax.set_facecolor(color)
    ax.set(
        title = 
        "Shade of blue is probability of moving to each cell from "+str(cell_coord[i])+
        "\nShoot probability: "+str(round(shoot_p,2))+
        " | Goal probability: "+str(round(goal_p,2))
        #"\nExpected Threat: "+str(round(xt,2)) + " (red is highest)"
    )
    a = .38
    b = .3
    x0 = ((4.376471 + 3.623529)/2)
    y0 = ((14.7804 + 15.12)/2)-.12
    x = (np.linspace(-a + x0, a + x0))
    y = -b * np.sqrt(1 - ((x - x0) / a) ** 2) + y0
    ax.plot(y, x,color='black')

    ax.plot([14.7804,15.12], [4.376471,4.376471],color='black')
    ax.plot([14.7804,15.12], [3.623529,3.623529],color='black')

    ax.plot([15.12,15.12], [0,8],color='black')
    ax.plot([15.12+0.2664,15.12+0.2664], [4-0.24,4+0.24],color='black')

    ax.plot([15.12,15.12+0.2664], [4-0.24,4-0.24],color='black')
    ax.plot([15.12,15.12+0.2664], [4+0.24,4+0.24],color='black')

    ax.plot([8,8], [0,8],color='black')
    ax.plot([10.04,10.04], [0,8],color='black')
    ax.plot([5.96,5.96], [0,8],color='black')
    plt.savefig('xt_gif_images/'+str(i)+'.png', dpi=100) 
    plt.clf()

files = glob.glob("gif_images/*.png")
files.sort(key=os.path.getmtime)

fp_out = 'GIF_transition_matrix2.gif'

img, *imgs = [Image.open(f) for f in files]
img.save(fp=fp_out, format='GIF', append_images=imgs,
         save_all=True, duration=500, loop=0)
# Out:
# # iterations:  17
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-b4d2bc003e56> in <module>
#      78     ax.plot([10.04,10.04], [0,8],color='black')
#      79     ax.plot([5.96,5.96], [0,8],color='black')
# ---> 80     plt.savefig('xt_gif_images/'+str(i)+'.png', dpi=100)
#      81     plt.clf()
#      82
#
# c:\users\3791150\appdata\local\programs\python\python37\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     858     fig = gcf()
#     859     res = fig.savefig(*args, **kwargs)
# --> 860     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     861     return res
#     862
#
# c:\users\3791150\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
#    2010         if not self._is_idle_drawing:
#    2011             with self._idle_draw_cntx():
# -> 2012                 self.draw(*args, **kwargs)
#    2013
#    2014     @cbook.deprecated("3.2")
#
# c:\users\3791150\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     405              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     406               else nullcontext()):
# --> 407             self.figure.draw(self.renderer)
#     408             # A GUI class may be need to update a window using this draw, so
#     409             # don't forget to call the superclass.
#
# c:\users\3791150\appdata\local\programs\python\python37\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# c:\users\3791150\appdata\local\programs\python\python37\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1862             self.patch.draw(renderer)
#    1863             mimage._draw_list_compositing_images(
# -> 1864                 renderer, self, artists, self.suppressComposite)
#    1865
#    1866             renderer.close_group('figure')
#
# c:\users\3791150\appdata\local\programs\python\python37\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# c:\users\3791150\appdata\local\programs\python\python37\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# c:\users\3791150\appdata\local\programs\python\python37\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# c:\users\3791150\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2745             renderer.stop_rasterizing()
#    2746
# -> 2747         mimage._draw_list_compositing_images(renderer, self, artists)
#    2748
#    2749         renderer.close_group('axes')
#
# c:\users\3791150\appdata\local\programs\python\python37\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# c:\users\3791150\appdata\local\programs\python\python37\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# c:\users\3791150\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1174         # the actual bbox
#    1175
# -> 1176         self._update_label_position(renderer)
#    1177
#    1178         self.label.draw(renderer)
#
# c:\users\3791150\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axis.py in _update_label_position(self, renderer)
#    2066                 spine = self.axes.spines['bottom']
#    2067                 spinebbox = spine.get_transform().transform_path(
# -> 2068                     spine.get_path()).get_extents()
#    2069             except KeyError:
#    2070                 # use axes if spine doesn't exist
#
# c:\users\3791150\appdata\local\programs\python\python37\lib\site-packages\matplotlib\path.py in get_extents(self, transform, **kwargs)
#     602             xys = np.concatenate(xys)
#     603         if len(xys):
# --> 604             return Bbox([xys.min(axis=0), xys.max(axis=0)])
#     605         else:
#     606             return Bbox.null()
#
# c:\users\3791150\appdata\local\programs\python\python37\lib\site-packages\matplotlib\transforms.py in __init__(self, points, **kwargs)
#     772         """
#     773         BboxBase.__init__(self, **kwargs)
# --> 774         points = np.asarray(points, float)
#     775         if points.shape != (2, 2):
#     776             raise ValueError('Bbox points must be of the form '
#
# c:\users\3791150\appdata\local\programs\python\python37\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# KeyboardInterrupt:

# %%
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
def getImage(path): 
    return OffsetImage(plt.imread(path), zoom=.3)

figure = plt.gcf()
figure.set_size_inches((200/15)+1, (85/15)+1)
ax = sns.heatmap(uniform_data,cmap="Blues",mask=mask)
ax.set_facecolor(color)
ax.set(
    title = 
    "Current cell "+str(cell_coord[i])+
    "\nColor: probability of moving to each cell"+
    "\nShoot probability: "+str(round(shoot_p,2))+
    " | Goal probability: "+str(round(goal_p,2))+
    "\nExpected Threat: "+str(round(xt,2))
)

a = .38
b = .3
x0 = ((4.376471 + 3.623529)/2)
y0 = ((14.7804 + 15.12)/2)-.12
x = (np.linspace(-a + x0, a + x0))
y = -b * np.sqrt(1 - ((x - x0) / a) ** 2) + y0
ax.plot(y, x,color='black')

ax.plot([14.7804,15.12], [4.376471,4.376471],color='black')
ax.plot([14.7804,15.12], [3.623529,3.623529],color='black')

ax.plot([15.12,15.12], [0,8],color='black')
ax.plot([15.12+0.2664,15.12+0.2664], [4-0.24,4+0.24],color='black')

ax.plot([15.12,15.12+0.2664], [4-0.24,4-0.24],color='black')
ax.plot([15.12,15.12+0.2664], [4+0.24,4+0.24],color='black')

ax.plot([8,8], [0,8],color='black')
ax.plot([10.04,10.04], [0,8],color='black')
ax.plot([5.96,5.96], [0,8],color='black')
