# %%
import sys
module_path = '../HockeynxT/'
if module_path not in sys.path:
    sys.path.append(module_path)
import xTHockey as xT
import pandas as pd

data=pd.read_csv('data.csv')
data=data[data['league'] == 'scouting']
results=xT.return_xT_values(data)
# Out:
# Time remaining in period, bin:  1
# # iterations:  17
# Time remaining in period, bin:  2
# # iterations:  3
# Time remaining in period, bin:  3
# # iterations:  8
# Time remaining in period, bin:  4
# # iterations:  4

# %%
results
# Out:
#          game_date    Home.Team       Away.Team  Period  Clock  \
# index
# 50884   2019-09-20  Erie Otters  Sudbury Wolves       1  20:00
# 50885   2019-09-20  Erie Otters  Sudbury Wolves       1  19:58
# 50886   2019-09-20  Erie Otters  Sudbury Wolves       1  19:53
# 50887   2019-09-20  Erie Otters  Sudbury Wolves       1  19:52
# 50888   2019-09-20  Erie Otters  Sudbury Wolves       1  19:51
# ...            ...          ...             ...     ...    ...
# 126752  2020-03-08  Erie Otters  Saginaw Spirit       3   0:07
# 126753  2020-03-08  Erie Otters  Saginaw Spirit       3   0:06
# 126754  2020-03-08  Erie Otters  Saginaw Spirit       3   0:04
# 126755  2020-03-08  Erie Otters  Saginaw Spirit       3   0:03
# 126756  2020-03-08  Erie Otters  Saginaw Spirit       3   0:01
#
#         Home.Team.Skaters  Away.Team.Skaters  Home.Team.Goals  \
# index
# 50884                   5                  5                0
# 50885                   5                  5                0
# 50886                   5                  5                0
# 50887                   5                  5                0
# 50888                   5                  5                0
# ...                   ...                ...              ...
# 126752                  6                  5                3
# 126753                  6                  5                3
# 126754                  6                  5                3
# 126755                  6                  5                3
# 126756                  6                  5                3
#
#         Away.Team.Goals            Team  ... home pos_skaters  def_skaters  \
# index                                    ...
# 50884                 0  Sudbury Wolves  ...    0           5            5
# 50885                 0  Sudbury Wolves  ...    0           5            5
# 50886                 0  Sudbury Wolves  ...    0           5            5
# 50887                 0     Erie Otters  ...    1           5            5
# 50888                 0     Erie Otters  ...    1           5            5
# ...                 ...             ...  ...  ...         ...          ...
# 126752                4     Erie Otters  ...    1           6            5
# 126753                4     Erie Otters  ...    1           6            5
# 126754                4     Erie Otters  ...    1           6            5
# 126755                4     Erie Otters  ...    1           6            5
# 126756                4     Erie Otters  ...    1           6            5
#
#         end_x end_y turnover game_time_remaining time goal        xT
# index
# 50884    67.0  77.0        0                4800    1    0  0.006980
# 50885    45.0  49.0        0                4798    1    0  0.003620
# 50886   111.0  49.0        1                4793    1    0  0.002931
# 50887    82.0  49.0        0                4792    1    0  0.004644
# 50888   136.0  10.0        1                4791    1    0  0.004282
# ...       ...   ...      ...                 ...  ...  ...       ...
# 126752  184.0   7.0        0                1207    4    0  0.017383
# 126753  190.0  14.0        0                1206    4    0  0.017383
# 126754  138.0  26.0        0                1204    4    0  0.020863
# 126755  181.0  75.0        0                1203    4    0  0.021847
# 126756    NaN   NaN        0                1201    4    0       NaN
#
# [75873 rows x 33 columns]
